# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.append(str(project_root / "scripts"))

from event_utils import (
    load_events,
    compute_surprise,
    upcoming_events,
    biggest_surprises,
    reaction_by_asset,
    top_macro_shocks,
    inflation_shock_indicator,
    classify_surprise,
    reaction_consistency,
    event_snapshot,
)

# %%
events = load_events()
events = compute_surprise(events)

events.head()
# Out:
#          date   time country event   category  previous  forecast  actual  \
# 0  2026-03-10  14:30      US   CPI  inflation       3.1       3.2     3.4
# 1  2026-03-10  14:30      US   CPI  inflation       3.1       3.2     3.4
# 2  2026-03-10  14:30      US   CPI  inflation       3.1       3.2     3.4
# 3  2026-03-10  14:30      US   CPI  inflation       3.1       3.2     3.4
# 4  2026-03-10  14:30      US   CPI  inflation       3.1       3.2     3.4
#
#     asset  move             market_reaction  \
# 0   UST2Y  0.10  yields up after hotter CPI
# 1  UST10Y  0.07  yields up after hotter CPI
# 2     DXY  0.45          dollar strengthens
# 3     SPX -0.90               equities fall
# 4    GOLD  0.30        gold slightly higher
#
#                                    notes  surprise
# 0        front-end reprices higher rates       0.2
# 1        long-end follows inflation risk       0.2
# 2   higher rate expectations support USD       0.2
# 3  valuation pressure from higher yields       0.2
# 4       safe-haven demand offsets yields       0.2

# %%
biggest_surprises(events)
# Out:
#           date   time country                  event category  previous  \
# 5   2026-03-12  13:30      US                    NFP   labour     210.0
# 6   2026-03-12  13:30      US                    NFP   labour     210.0
# 7   2026-03-12  13:30      US                    NFP   labour     210.0
# 8   2026-03-12  13:30      US                    NFP   labour     210.0
# 14  2026-03-16  03:00      CN  Industrial Production   growth       5.2
#
#     forecast  actual  asset  move market_reaction  \
# 5      190.0   250.0  UST2Y  0.08     yields rise
# 6      190.0   250.0    DXY  0.35       dollar up
# 7      190.0   250.0    SPX  0.40     equities up
# 8      190.0   250.0   GOLD -0.50      gold falls
# 14       5.0     4.6    OIL -1.20       oil drops
#
#                                 notes  surprise  abs_surprise
# 5   strong labor supports hawkish Fed      60.0          60.0
# 6                   strong macro data      60.0          60.0
# 7           growth optimism dominates      60.0          60.0
# 8                    real yields rise      60.0          60.0
# 14              weaker demand outlook      -0.4           0.4

# %%
reaction_by_asset(events, "UST10Y")
# Out:
#           date              event  surprise  move
# 1   2026-03-10                CPI       0.2  0.07
# 10  2026-03-14  ECB Rate Decision       0.0  0.02

# %%
reaction_by_asset(events, "DXY")
# Out:
#           date          event  surprise  move
# 2   2026-03-10            CPI       0.2  0.45
# 6   2026-03-12            NFP      60.0  0.35
# 19  2026-03-19  FOMC Decision       0.0  0.60

# %%
reaction_by_asset(events, "SPX")
# Out:
#           date                  event  surprise  move
# 3   2026-03-10                    CPI       0.2  -0.9
# 7   2026-03-12                    NFP      60.0   0.4
# 11  2026-03-14      ECB Rate Decision       0.0  -0.3
# 13  2026-03-16  Industrial Production      -0.4  -0.2
# 20  2026-03-19          FOMC Decision       0.0  -1.1

# %%
top_macro_shocks(events)
# Out:
#          date country                  event   category  surprise  \
# 1  2026-03-12      US                    NFP     labour      60.0
# 3  2026-03-16      CN  Industrial Production     growth      -0.4
# 4  2026-03-18      UK                    CPI  inflation      -0.3
#
#                                notes  abs_surprise
# 1  strong labor supports hawkish Fed          60.0
# 3              growth disappointment           0.4
# 4                   softer inflation           0.3

# %%
inflation_shock_indicator(events)
# Out:
# 'Inflation running HOT'

# %%
events_labeled = classify_surprise(events)

events_labeled[["date", "event", "asset", "surprise", "surprise_label"]]
# Out:
#           date                  event    asset  surprise surprise_label
# 0   2026-03-10                    CPI    UST2Y       0.2       moderate
# 1   2026-03-10                    CPI   UST10Y       0.2       moderate
# 2   2026-03-10                    CPI      DXY       0.2       moderate
# 3   2026-03-10                    CPI      SPX       0.2       moderate
# 4   2026-03-10                    CPI     GOLD       0.2       moderate
# 5   2026-03-12                    NFP    UST2Y      60.0     very large
# 6   2026-03-12                    NFP      DXY      60.0     very large
# 7   2026-03-12                    NFP      SPX      60.0     very large
# 8   2026-03-12                    NFP     GOLD      60.0     very large
# 9   2026-03-14      ECB Rate Decision   EURUSD       0.0           none
# 10  2026-03-14      ECB Rate Decision   UST10Y       0.0           none
# 11  2026-03-14      ECB Rate Decision      SPX       0.0           none
# 12  2026-03-16  Industrial Production   USDCNH      -0.4     very large
# 13  2026-03-16  Industrial Production      SPX      -0.4     very large
# 14  2026-03-16  Industrial Production      OIL      -0.4     very large
# 15  2026-03-18                    CPI  GILT10Y      -0.3       moderate
# 16  2026-03-18                    CPI   GBPUSD      -0.3       moderate
# 17  2026-03-18                    CPI     FTSE      -0.3       moderate
# 18  2026-03-19          FOMC Decision    UST2Y       0.0           none
# 19  2026-03-19          FOMC Decision      DXY       0.0           none
# 20  2026-03-19          FOMC Decision      SPX       0.0           none
# 21  2026-03-19          FOMC Decision     GOLD       0.0           none

# %%
events_checked = reaction_consistency(events)

events_checked
# Out:
#           date                  event    asset  surprise  move  \
# 0   2026-03-10                    CPI    UST2Y       0.2  0.10
# 1   2026-03-10                    CPI   UST10Y       0.2  0.07
# 2   2026-03-10                    CPI      DXY       0.2  0.45
# 3   2026-03-10                    CPI      SPX       0.2 -0.90
# 4   2026-03-10                    CPI     GOLD       0.2  0.30
# 5   2026-03-12                    NFP    UST2Y      60.0  0.08
# 6   2026-03-12                    NFP      DXY      60.0  0.35
# 7   2026-03-12                    NFP      SPX      60.0  0.40
# 8   2026-03-12                    NFP     GOLD      60.0 -0.50
# 9   2026-03-14      ECB Rate Decision   EURUSD       0.0  0.20
# 10  2026-03-14      ECB Rate Decision   UST10Y       0.0  0.02
# 11  2026-03-14      ECB Rate Decision      SPX       0.0 -0.30
# 12  2026-03-16  Industrial Production   USDCNH      -0.4  0.25
# 13  2026-03-16  Industrial Production      SPX      -0.4 -0.20
# 14  2026-03-16  Industrial Production      OIL      -0.4 -1.20
# 15  2026-03-18                    CPI  GILT10Y      -0.3 -0.12
# 16  2026-03-18                    CPI   GBPUSD      -0.3 -0.40
# 17  2026-03-18                    CPI     FTSE      -0.3  0.50
# 18  2026-03-19          FOMC Decision    UST2Y       0.0  0.15
# 19  2026-03-19          FOMC Decision      DXY       0.0  0.60
# 20  2026-03-19          FOMC Decision      SPX       0.0 -1.10
# 21  2026-03-19          FOMC Decision     GOLD       0.0 -0.80
#
#    expected_direction actual_direction  reaction_match
# 0                  up               up            True
# 1                  up               up            True
# 2                  up               up            True
# 3                down             down            True
# 4             unclear               up           False
# 5             unclear               up           False
# 6             unclear               up           False
# 7             unclear               up           False
# 8             unclear             down           False
# 9             unclear               up           False
# 10            unclear               up           False
# 11            unclear             down           False
# 12            unclear               up           False
# 13            unclear             down           False
# 14            unclear             down           False
# 15            unclear             down           False
# 16            unclear             down           False
# 17            unclear               up           False
# 18            unclear               up           False
# 19            unclear               up           False
# 20            unclear             down           False
# 21            unclear             down           False

# %%
event_snapshot(events, "CPI", "2026-03-10")
# Out:
#          date   time country event   asset  move             market_reaction  \
# 2  2026-03-10  14:30      US   CPI     DXY  0.45          dollar strengthens
# 4  2026-03-10  14:30      US   CPI    GOLD  0.30        gold slightly higher
# 3  2026-03-10  14:30      US   CPI     SPX -0.90               equities fall
# 1  2026-03-10  14:30      US   CPI  UST10Y  0.07  yields up after hotter CPI
# 0  2026-03-10  14:30      US   CPI   UST2Y  0.10  yields up after hotter CPI
#
#                                    notes  surprise
# 2   higher rate expectations support USD       0.2
# 4       safe-haven demand offsets yields       0.2
# 3  valuation pressure from higher yields       0.2
# 1        long-end follows inflation risk       0.2
# 0        front-end reprices higher rates       0.2
