# %%
events = load_events()
events = compute_surprise(events)
events.head()

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.append(str(project_root / "scripts"))

from event_utils import load_events, compute_surprise, upcoming_events
